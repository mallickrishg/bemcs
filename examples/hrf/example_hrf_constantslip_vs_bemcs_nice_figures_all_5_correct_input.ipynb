# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = "retina"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload

import bemcs

def construct_kernels_centralnode(fileinput, els, kernels_s, kernels_n, traction_kernels_s, traction_kernels_n, matrix_slip):
    bctype_x = fileinput["bc_type_x"].values
    bctype_y = fileinput["bc_type_y"].values
    labels = fileinput["collection"].values
    
    n_els = len(els.x1)
    Nunknowns = 6 * n_els

    # Linear operator for central node BCs
    kerneleval_x = np.zeros((n_els, Nunknowns))
    kerneleval_y = np.zeros((n_els, Nunknowns))

    # x,y-kernels
    for i in np.unique(labels):
        index = np.where(labels == i)[0]
        for j in index:
            if bctype_x[j] == "u_global":
                for k in range(0, 3):
                    kerneleval_x[j, k::6] = kernels_s[3][j, k::3]
                    kerneleval_x[j, k + 3 :: 6] = kernels_n[3][j, k::3]
            elif bctype_x[j] == "t_local":
                for k in range(0, 3):
                    kerneleval_x[j, k::6] = traction_kernels_s[0][j, k::3]
                    kerneleval_x[j, k + 3 :: 6] = traction_kernels_n[0][j, k::3]
            elif bctype_x[j] == "s_local":
                kerneleval_x[j, :] = matrix_slip[2::6, :][j, :]
            else:
                raise ValueError("unrecognized boundary condition type")

            if bctype_y[j] == "u_global":
                for k in range(0, 3):
                    kerneleval_y[j, k::6] = kernels_s[4][j, k::3]
                    kerneleval_y[j, k + 3 :: 6] = kernels_n[4][j, k::3]
            elif bctype_y[j] == "t_local":
                for k in range(0, 3):
                    kerneleval_y[j, k::6] = traction_kernels_s[1][j, k::3]
                    kerneleval_y[j, k + 3 :: 6] = traction_kernels_n[1][j, k::3]
            elif bctype_y[j] == "s_local":
                kerneleval_y[j, :] = matrix_slip[3::6, :][j, :]
            else:
                raise ValueError("unrecognized boundary condition type")
            
    return kerneleval_x,kerneleval_y

def extract_quadratic_components(quadratic_coefs, n_els):
    # extract (s,n) components and store them in 2 separate vectors
    quadratic_coefs_s = np.zeros((3 * n_els, 1))
    quadratic_coefs_n = np.zeros((3 * n_els, 1))
    for i in range(n_els):
        quadratic_coefs_s[3 * i : 3 * (i + 1)] = quadratic_coefs[6 * i : 6 * i + 3]
        quadratic_coefs_n[3 * i : 3 * (i + 1)] = quadratic_coefs[6 * i + 3 : 6 * (i + 1)]
    
    return quadratic_coefs_s,quadratic_coefs_n

# %% [markdown]
# ## Main Himalayan Thrust BEM experiment
# In this numerical experiment we construct a model of the 2015 Gorkha earthquake that had 4-6 m of coseismic slip along the deeper "flat" structure of the MHT. We compare a traditional constant slip BEM approach with solutions using our new "smooth slip" formulation (`bemcs`)
#
# Going from the quadratic basis function formulation in `bemcs` to constant basis is simple. We take the kernels that we constructed for the quadratic nodes and sum each of the 3 kernel partials to get the constant kernel. Note that these kernels can be either 'slip', 'displacement' or 'traction' kernels.
#
# In practice, if the quadratic kernel is of the form for 2 fault elements $a$ and $b$:
#
# $K_q = \begin{bmatrix}
# \phi^s_{a1} & \phi^s_{a2} & \phi^s_{a3} & \phi^n_{a1} & \phi^n_{a2} & \phi^n_{a3} &
# \phi^s_{b1} & \phi^s_{b2} & \phi^s_{b3} & \phi^n_{b1} & \phi^n_{b2} & \phi^n_{b3} & ... \\
# \vdots & & & \vdots & & & \vdots & & & \vdots & & & ...
# \end{bmatrix}$
#
# then the constant slip kernel $K_c$ can be computes as:
#
# $K_c = \begin{bmatrix}
# \phi^s_{a1} + \phi^s_{a2} + \phi^s_{a3} & \phi^n_{a1} + \phi^n_{a2} + \phi^n_{a3} &
# \phi^s_{b1} + \phi^s_{b2} + \phi^s_{b3} & \phi^n_{b1} + \phi^n_{b2} + \phi^n_{b3} & ... \\
# \vdots & \vdots & \vdots & \vdots & ...
# \end{bmatrix}$

# %% [markdown]
# # Material properties

# %%
mu = 3e10
nu = 0.25
save_figures = False

# %% [markdown]
# # BEM solve and evaluate functions

# %%
def build_and_solve_bem(file_name, mu, nu, element_type="smooth_slip"):
    # read fault geometry files
    fileinput = pd.read_csv(file_name)

    # print(fileinput.head())
    x1 = fileinput["x1"].values
    x2 = fileinput["x2"].values
    y1 = fileinput["y1"].values
    y2 = fileinput["y2"].values
    bc_x = fileinput["bc_x"].values
    bc_y = fileinput["bc_y"].values
    bctype_x = fileinput["bc_type_x"].values
    bctype_y = fileinput["bc_type_y"].values

    labels = fileinput["collection"].values
    print(np.unique(labels))

    # create bemcs data structure
    els = bemcs.initialize_els()
    els.x1 = x1
    els.y1 = y1
    els.x2 = x2
    els.y2 = y2
    bemcs.standardize_els_geometry(els)
    n_els = len(els.x1)

    # Identifying open nodes, overlapping interior nodes and triple junctions automatically
    index_open, index_overlap, index_triple = bemcs.label_nodes(els)
    N_c = 2 * n_els  # central node equations
    N_o = 2 * len(index_open)  # open node equations
    N_i = 4 * len(index_overlap)  # overlapping node equations
    N_t = 6 * len(index_triple)  # triple junction equations
    Nunknowns = 6 * n_els

    # We will stack this with:
    # 1. Equations for the element centers
    # 2. Equations at open nodes (RHS = 0)
    # 3. Equations at overlapping nodes (RHS = 0)
    # 4, Equations at triple junctions (RHS = 0)
    BC_c = np.zeros((N_c, 1))  # these are the only non-zero entries
    BC_o = np.zeros((N_o, 1))
    BC_i = np.zeros((N_i, 1))
    BC_t = np.zeros((N_t, 1))

    # Apply BCs at central nodes
    BC_c[0::2, 0] = bc_x
    BC_c[1::2, 0] = bc_y

    # Atack all the BCs into one big vector
    BCvector = np.vstack((BC_c, BC_o, BC_i, BC_t))

    # Design Matrix System
    # - At element centers, we implement either displacement, slip or traction boundary conditions
    # - At open nodes, we force slip to be 0
    # - At 2-overlap (interior) nodes we have continuity & smoothness of slip
    # - At triple junctions, we implement 2 equations for conservation of slip and 4 equations for smoothness
    # Design matrices (in x,y coordinates) for slip and slip gradients at each 3qn
    matrix_slip, matrix_slip_gradient = bemcs.get_matrices_slip_slip_gradient(
        els, reference="local"
    )

    # Patch center locations
    # (need to be shifted an infinitesimal amount in unit normal direction for displacement bcs)
    epsilonr = 1e-6 * (bctype_x == "u_global").astype(float)
    obs_xy = np.vstack((els.x_centers, els.y_centers)).T
    x_obs = (obs_xy[:, 0] + epsilonr * els.x_normals).reshape(-1, 1)
    y_obs = (obs_xy[:, 1] + epsilonr * els.y_normals).reshape(-1, 1)

    # Compute shear and tensile stress kernels evaluated ONLY at the center of each element
    kernels_s = bemcs.get_displacement_stress_kernel(x_obs, y_obs, els, mu, nu, "shear")
    kernels_n = bemcs.get_displacement_stress_kernel(
        x_obs, y_obs, els, mu, nu, "normal"
    )

    # Convert to traction kernels [Nobs x Ncoefficients]
    traction_kernels_s = bemcs.get_traction_kernels(els, kernels_s, flag="local")
    traction_kernels_n = bemcs.get_traction_kernels(els, kernels_n, flag="local")

    # Construct linear operator and solve system
    # Linear operators for the appropriate boundary conditions
    matrix_system_c = np.zeros((N_c, Nunknowns))
    kerneleval_x, kerneleval_y = construct_kernels_centralnode(
        fileinput,
        els,
        kernels_s,
        kernels_n,
        traction_kernels_s,
        traction_kernels_n,
        matrix_slip,
    )

    # Populate matrix_system for central nodes
    matrix_system_c[0::2, :] = kerneleval_x
    matrix_system_c[1::2, :] = kerneleval_y
    matrix_system_o, matrix_system_i, matrix_system_t = bemcs.construct_smoothoperator(
        els, index_open, index_overlap, index_triple
    )

    # Stack the matrices and create the full linear operator
    matrix_system = np.vstack(
        (matrix_system_c, matrix_system_o, matrix_system_i, matrix_system_t)
    )

    # Compute quadratic node coefficients (in local (s,n) coordinates)
    coefs = np.linalg.inv(matrix_system) @ BCvector

    if element_type == "constant_slip":
        ### START Paste of stuff for constant slip case
        # # provide new input file for locked system with appropriate BCs
        # bc_x = fileinput["bc_x"].values
        # bc_y = fileinput["bc_y"].values
        BC_constant = np.zeros((N_c, 1))
        BC_constant[0::2, 0] = bc_x
        BC_constant[1::2, 0] = bc_y

        # Linear Operators for the appropriate boundary conditions
        # Note that we now only need to evaluate BCs at the center of each node, so the size of the operator is smaller than before
        matrix_system_constant = np.zeros((N_c, N_c))
        kernelconst_x = np.zeros((n_els, N_c))
        kernelconst_y = np.zeros((n_els, N_c))

        # To construct a constant slip kernel, simply sum the 3 quadratic terms i.e., each set of 3 columns from the original kernels
        for i in range(N_c):
            kernelconst_x[:, i] = np.sum(kerneleval_x[:, i * 3 : 3 * (i + 1)], axis=1)
            kernelconst_y[:, i] = np.sum(kerneleval_y[:, i * 3 : 3 * (i + 1)], axis=1)

        # Populate matrix_system for central nodes
        matrix_system_constant[0::2, :] = kernelconst_x
        matrix_system_constant[1::2, :] = kernelconst_y

        # Compute quadratic node coefficients (in local (s,n) coordinates)
        coefs_constant = np.linalg.inv(matrix_system_constant) @ BC_constant

        # Take constant slip state vector and create quadratic vector with copied constant_coefs values
        coefs = np.zeros((6 * n_els, 1))
        coefs[0::3] = coefs_constant
        coefs[1::3] = coefs_constant
        coefs[2::3] = coefs_constant
        ### END Past of stuff for constant slip case

    return els, coefs


def evaluate_bem_solution(x_obs, y_obs, els, mu, nu, coefs):
    n_els = len(els.x1)

    # Compute shear and tensile stress kernels
    kernels_shear = bemcs.get_displacement_stress_kernel(
        x_obs, y_obs, els, mu, nu, "shear"
    )
    kernels_normal = bemcs.get_displacement_stress_kernel(
        x_obs, y_obs, els, mu, nu, "normal"
    )

    # Quadratic element case
    # extract (s,n) components and store them in 2 separate vectors
    coefs_shear = np.zeros((3 * n_els, 1))
    coefs_normal = np.zeros((3 * n_els, 1))
    for i in range(n_els):
        coefs_shear[3 * i : 3 * (i + 1)] = coefs[6 * i : 6 * i + 3]
        coefs_normal[3 * i : 3 * (i + 1)] = coefs[6 * i + 3 : 6 * (i + 1)]

    # Compute displacement and stresses (we will plot it later)
    ux, uy, sxx, syy, sxy = bemcs.coeffs_to_disp_stress(
        kernels_shear, kernels_normal, coefs_shear, coefs_normal
    )

    strain_energy_plane_strain = bemcs.get_strain_from_stress(
        sxx, syy, sxy, mu, nu, conversion="plane_strain"
    )

    return ux, uy, sxx, syy, sxy, strain_energy_plane_strain

# %% [markdown]
# # BEM solve (6 cases)
# 1. Interseismic smooth slip
# 2. Interseismic constant slip
# 3. Interseismic constant slip (3x elements)
# 4. Coseismic smooth slip
# 5. Coseismic constant slip
# 6. Coseismic constant slip (3x elements)

# %%
# 1. Interseismic (smooth slip)
input_file_interseismic = "mht_geometry_locked_5_km.csv"
els, coefs_interseismic_smooth = build_and_solve_bem(
    input_file_interseismic, mu, nu, element_type="smooth_slip"
)

# 2. Interseismic (constant slip)
input_file_interseismic = "mht_geometry_locked_5_km.csv"
els, coefs_interseismic_constant = build_and_solve_bem(
    input_file_interseismic, mu, nu, element_type="constant_slip"
)

# 3. Interseismic (constant slip, 3x resolution)
input_file_interseismic = "mht_geometry_locked_5_km_split_in_3.csv"
els_3, coefs_interseismic_constant_3 = build_and_solve_bem(
    input_file_interseismic, mu, nu, element_type="constant_slip"
)

# 4. Coseismic (smooth slip)
input_file_coseismic = "mht_geometry_gorkha_5_km.csv"
els, coefs_coseismic_smooth = build_and_solve_bem(
    input_file_coseismic, mu, nu, element_type="smooth_slip"
)

# 5. Coseismic (constant slip)
input_file_coseismic = "mht_geometry_gorkha_5_km.csv"
els, coefs_coseismic_constant = build_and_solve_bem(
    input_file_coseismic, mu, nu, element_type="constant_slip"
)

# 6. Coseismic (constant slip, 3x resolution)
input_file_coseismic = "mht_geometry_gorkha_5_km_split_in_3.csv"
els_3, coefs_coseismic_constant_3 = build_and_solve_bem(
    input_file_coseismic, mu, nu, element_type="constant_slip"
)

n_els = len(els.x1)
n_els_3 = len(els_3.x1)
# Out:
# ['left_topo' 'mbt' 'ramp_mft' 'right_edge' 'right_topo' 'topo']
# Number of open nodes = 2
# : [array([393]), array([695])]
# Number of 2-overlap nodes = 324
# : [array([ 396, -395]), array([ 399, -398]), array([ 402, -401]), array([ 405, -404]), array([ 408, -407]), array([ 411, -410]), array([ 414, -413]), array([ 417, -416]), array([ 420, -419]), array([ 423, -422]), array([ 426, -425]), array([ 429, -428]), array([ 432, -431]), array([ 435, -434]), array([ 438, -437]), array([ 441, -440]), array([ 444, -443]), array([ 447, -446]), array([ 450, -449]), array([ 453, -452]), array([ 456, -455]), array([ 459, -458]), array([ 462, -461]), array([ 465, -464]), array([ 468, -467]), array([ 471, -470]), array([ 474, -473]), array([ 477, -476]), array([ 480, -479]), array([ 483, -482]), array([ 486, -485]), array([ 489, -488]), array([ 492, -491]), array([ 495, -494]), array([ 498, -497]), array([ 
81, -80]), array([ 285, -284]), array([ 84, -83]), array([ 87, -86]), array([ 90, -89]), array([ 288, -287]), array([ 93, -92]), array([ 96, -95]), array([ 291, -290]), array([ 99, -98]), array([ 294, -293]), array([ 102, -101]), array([ 105, -104]), array([ 297, -296]), array([ 108, -107]), array([ 111, -110]), array([ 300, -299]), array([ 114, -113]), array([ 117, -116]), array([ 120, -119]), array([ 303, -302]), array([ 123, -122]), array([ 306, -305]), array([ 126, -125]), array([ 129, -128]), array([ 132, -131]), array([ 309, -308]), array([ 135, -134]), array([ 312, -311]), array([ 138, -137]), array([ 141, -140]), array([ 315, -314]), array([ 144, -143]), array([ 147, -146]), array([ 318, -317]), array([ 150, -149]), array([ 321, -320]), array([ 153, -152]), array([ 156, -155]), array([ 324, -323]), array([ 159, -158]), array([ 162, -161]), array([ 165, -164]), array([ 168, -167]), array([ 327, -326]), array([ 171, -170]), array([ 174, -173]), array([ 330, -329]), array([ 177, -176]), array([ 333, -332]), array([ 180, -179]), array([ 336, -335]), array([ 183, -182]), array([ 186, -185]), array([ 339, -338]), array([ 189, -188]), array([ 19 ...
# Number of triple junctions = 4
# : [array([  -9, -249,    8]), array([ -33, -237,   32]), array([ 276, -248, -275]), array([ 990, -236, -392])]
# /Users/meade/Desktop/bemcs/bemcs/bemcs.py:149: RuntimeWarning: divide by zero encountered in divide
#   arctan_x_minus_a = np.pi / 2 * np.sign(y / (a - x)) - np.arctan(y / (a - x))
# /Users/meade/Desktop/bemcs/bemcs/bemcs.py:150: RuntimeWarning: divide by zero encountered in divide
#   arctan_x_plus_a = np.pi / 2 * np.sign(y / (a + x)) - np.arctan(y / (a + x))
# ['left_topo' 'mbt' 'ramp_mft' 'right_edge' 'right_topo' 'topo']
# Number of open nodes = 2
# : [array([393]), array([695])]
# Number of 2-overlap nodes = 324
# : [array([ 396, -395]), array([ 399, -398]), array([ 402, -401]), array([ 405, -404]), array([ 408, -407]), array([ 411, -410]), array([ 414, -413]), array([ 417, -416]), array([ 420, -419]), array([ 423, -422]), array([ 426, -425]), array([ 429, -428]), array([ 432, -431]), array([ 435, -434]), array([ 438, -437]), array([ 441, -440]), array([ 444, -443]), array([ 447, -446]), array([ 450, -449]), array([ 453, -452]), array([ 456, -455]), array([ 459, -458]), array([ 462, -461]), array([ 465, -464]), array([ 468, -467]), array([ 471, -470]), array([ 474, -473]), array([ 477, -476]), array([ 480, -479]), array([ 483, -482]), array([ 486, -485]), array([ 489, -488]), array([ 492, -491]), array([ 495, -494]), array([ 498, -497]), array([ 501, -500]), array([ 504, -503]), array([ 507, -506]), array([ 510, -509]), array([ 513, -512]), array([ 516, -515]), array([ 519, -518]), array([ 522, -521]), array([ 525, -524]), array([ 528, -527]), array([ 531, -530]), array([ 534, -533]), array([ 537, -536]), array([ 540, -539]), array([ 543, -542]), array([ 546, -545]), array([ 549, -548]), array([ 552, -551]), array([ 555, -554]), array([ 558, -557]), array([ 561, -560]), array([ 564, -563]), array([ 567, -566]), array([ 570, -569]), array([ 573, -572]), array([ 576, -575]), array([ 579, -578]), array([ 582,
1539, -1538]), array([ 1542, -1541]), array([ 1545, -1544]), array([ 1548, -1547]), array([ 1551, -1550]), array([ 1554, -1553]), array([ 1557, -1556]), array([ 1560, -1559]), array([ 1563, -1562]), array([ 1566, -1565]), array([ 1569, -1568]), array([ 1572, -1571]), array([ 1575, -1574]), array([ 1578, -1577]), array([ 1581, -1580]), array([ 1584, -1583]), array([ 1587, -1586]), array([ 1590, -1589]), array([ 1593, -1592]), array([ 1596, -1595]), array([ 1599, -1598]), array([ 1602, -1601]), array([ 1605, -1604]), array([ 1608, -1607]), array([ 1611, -1610]), array([ 1614, -1613]), array([ 1617, -1616]), array([ 1620, -1619]), array([ 1623, -1622]), array([ 1626, -1625]), array([ 1629, -1628]), array([ 1632, -1631]), array([ 1635, -1634]), array([ 1638, -1637]), array([ 1641, -1640]), array([ 1644, -1643]), array([ 1647, -1646]), array([ 1650, -1649]), array([ 1653, -1652]), array([ 1656, -1655]), array([ 1659, -1658]), array([ 1662, -1661]), array([ 1665, -1664]), array([ 1668, -1667]), array([ 1671, -1670]), array([ 1674, -1673]), array([ 1677, -1676]), array([ 1680, -1679]), array([ 1683, -1682]), array([ 1686, -1685]), array([ 1689, -1688]), array([ 1692, -1691]), array([ 1695, -1694]), array([ 1698, -1697]), array([ 1701, -170 ...
# Number of triple junctions = 4
# : [array([ -27, -747,   26]), array([ -99, -711,   98]), array([ 828, -746, -827]), array([ 2976,  -710, -1178])]
# /Users/meade/Desktop/bemcs/bemcs/bemcs.py:149: RuntimeWarning: divide by zero encountered in divide
#   arctan_x_minus_a = np.pi / 2 * np.sign(y / (a - x)) - np.arctan(y / (a - x))
# /Users/meade/Desktop/bemcs/bemcs/bemcs.py:150: RuntimeWarning: divide by zero encountered in divide
#   arctan_x_plus_a = np.pi / 2 * np.sign(y / (a + x)) - np.arctan(y / (a + x))

# %% [markdown]
# # HACK: Convert Interseismic coefficients from mm/yr to m/s

# %%
mm_to_m = 1e-3
yr_to_s = 60 * 60 * 24 * 365
mm_per_year_to_m_per_s = mm_to_m / yr_to_s
unit_to_hrf_rate_scaling = 20
coefs_interseismic_smooth *= unit_to_hrf_rate_scaling * mm_per_year_to_m_per_s
coefs_interseismic_constant *= unit_to_hrf_rate_scaling * mm_per_year_to_m_per_s
coefs_interseismic_constant_3 *= unit_to_hrf_rate_scaling * mm_per_year_to_m_per_s

# %% [markdown]
# # Predicted deformation fields
# 1. Interseismic smooth slip
# 2. Interseismic constant slip
# 3. Interseismic constant slip (3x elements)
# 4. Coseismic smooth slip
# 5. Coseismic constant slip
# 6. Coseismic constant slip (3x elements)

# %%
# Observation points
n_obs = 50
x_obs = np.linspace(-200, 10, n_obs)
y_obs = np.linspace(-40, 10, n_obs)
x_obs, y_obs = np.meshgrid(x_obs, y_obs)
x_obs = x_obs.flatten()
y_obs = y_obs.flatten()

# 1. Interseismic (smooth slip)
(
    ux_interseismic_smooth,
    uy_interseismic_smooth,
    sxx_interseismic_smooth,
    syy_interseismic_smooth,
    sxy_interseismic_smooth,
    u_interseismic_smooth,
) = evaluate_bem_solution(x_obs, y_obs, els, mu, nu, coefs_interseismic_smooth)

# 2. Interseismic (constant slip)
(
    ux_interseismic_constant,
    uy_interseismic_constant,
    sxx_interseismic_constant,
    syy_interseismic_constant,
    sxy_interseismic_constant,
    u_interseismic_constant,
) = evaluate_bem_solution(x_obs, y_obs, els, mu, nu, coefs_interseismic_constant)

# 3. Interseismic (constant slip, 3x resolution)
(
    ux_interseismic_constant_3,
    uy_interseismic_constant_3,
    sxx_interseismic_constant_3,
    syy_interseismic_constant_3,
    sxy_interseismic_constant_3,
    u_interseismic_constant_3,
) = evaluate_bem_solution(x_obs, y_obs, els_3, mu, nu, coefs_interseismic_constant_3)

# 4. Coseismic (smooth slip)
(
    ux_coseismic_smooth,
    uy_coseismic_smooth,
    sxx_coseismic_smooth,
    syy_coseismic_smooth,
    sxy_coseismic_smooth,
    u_coseismic_smooth,
) = evaluate_bem_solution(x_obs, y_obs, els, mu, nu, coefs_coseismic_smooth)

# 5. Coseismic (constant slip)
(
    ux_coseismic_constant,
    uy_coseismic_constant,
    sxx_coseismic_constant,
    syy_coseismic_constant,
    sxy_coseismic_constant,
    u_coseismic_constant,
) = evaluate_bem_solution(x_obs, y_obs, els, mu, nu, coefs_coseismic_constant)

# 6. Coseismic (constant slip, 3x resolution)
(
    ux_coseismic_constant_3,
    uy_coseismic_constant_3,
    sxx_coseismic_constant_3,
    syy_coseismic_constant_3,
    sxy_coseismic_constant_3,
    u_coseismic_constant_3,
) = evaluate_bem_solution(x_obs, y_obs, els_3, mu, nu, coefs_coseismic_constant_3)

# %% [markdown]
# # Energy calculations
# 1. Interseismic smooth slip
# 2. Interseismic constant slip
# 3. Interseismic constant slip (3x elements)
# 4. Coseismic smooth slip
# 5. Coseismic constant slip
# 6. Coseismic constant slip (3x elements)
# 7. Interseismic 250 years
# 8. Interseeismic 500 years

# %%
def get_strain_energy(sxx, syy, sxy, mu, nu, conversion="plane_strain"):
    youngs_modulus = 2 * mu * (1 + nu)

    if conversion == "plane_strain":
        # print(f"{conversion=}")
        # Plane strain linear operator. I think this is Crouch and Starfield???
        stress_from_strain_plane_strain = (
            youngs_modulus
            / ((1 + nu) * (1 - 2 * nu))
            * np.array([[1 - nu, nu, 0], [nu, 1 - nu, 0], [0, 0, (1 - 2 * nu) / 2.0]])
        )
        strain_from_stress_plane_strain = np.linalg.inv(stress_from_strain_plane_strain)
        operator = np.copy(strain_from_stress_plane_strain)

    elif conversion == "plane_stress":
        # print(f"{conversion=}")
        # Plane stress linear operator
        strain_from_stress_plane_stress = (
            1
            / youngs_modulus
            * np.array([[1, -nu, 0], [-nu, 1, 0], [0, 0, 2 * (1 + nu)]])
        )
        operator = np.copy(strain_from_stress_plane_stress)

    # print(f"{operator}")

    # Calculate strains
    exx = np.zeros_like(sxx)
    exy = np.zeros_like(syy)
    eyy = np.zeros_like(sxy)
    for i in range(len(sxx)):
        stresses = np.array([sxx[i], syy[i], sxy[i]])
        exx[i], eyy[i], exy[i] = operator @ stresses

    # Calculate strain energy
    strain_energy = sxx * exx + syy * eyy + sxy * exy
    return strain_energy


# 1.
u_interseismic_constant = get_strain_energy(
    sxx_interseismic_constant,
    syy_interseismic_constant,
    sxy_interseismic_constant,
    mu,
    nu,
    conversion="plane_strain",
)

# 2.
u_interseismic_constant_3 = get_strain_energy(
    sxx_interseismic_constant_3,
    syy_interseismic_constant_3,
    sxy_interseismic_constant_3,
    mu,
    nu,
    conversion="plane_strain",
)

# 3.
u_interseismic_smooth = get_strain_energy(
    sxx_interseismic_smooth,
    syy_interseismic_smooth,
    sxy_interseismic_smooth,
    mu,
    nu,
    conversion="plane_strain",
)

# 4.
u_coseismic_constant = get_strain_energy(
    sxx_coseismic_constant,
    syy_coseismic_constant,
    sxy_coseismic_constant,
    mu,
    nu,
    conversion="plane_strain",
)

# 5.
u_coseismic_constant_3 = get_strain_energy(
    sxx_coseismic_constant_3,
    syy_coseismic_constant_3,
    sxy_coseismic_constant_3,
    mu,
    nu,
    conversion="plane_strain",
)

# 6.
u_coseismic_smooth = get_strain_energy(
    sxx_coseismic_smooth,
    syy_coseismic_smooth,
    sxy_coseismic_smooth,
    mu,
    nu,
    conversion="plane_strain",
)


# Time integrated interseismic strain energy
# 7. 250 years
years = 250
time_scale = yr_to_s * years
u_interseismic_smooth_250_years = get_strain_energy(
    time_scale * sxx_interseismic_smooth,
    time_scale * syy_interseismic_smooth,
    time_scale * sxy_interseismic_smooth,
    mu,
    nu,
    conversion="plane_strain",
)

# 8. 500 years
years = 500
time_scale = yr_to_s * years
u_interseismic_smooth_500_years = get_strain_energy(
    time_scale * sxx_interseismic_smooth,
    time_scale * syy_interseismic_smooth,
    time_scale * sxy_interseismic_smooth,
    mu,
    nu,
    conversion="plane_strain",
)

# 9. 1000 years
years = 1000
time_scale = yr_to_s * years
u_interseismic_smooth_1000_years = get_strain_energy(
    time_scale * sxx_interseismic_smooth,
    time_scale * syy_interseismic_smooth,
    time_scale * sxy_interseismic_smooth,
    mu,
    nu,
    conversion="plane_strain",
)

# %%
print("Coseismic constant")
bemcs.plot_displacements_stresses_els(
    els,
    n_obs,
    ux_coseismic_constant,
    uy_coseismic_constant,
    sxx_coseismic_constant,
    syy_coseismic_constant,
    sxy_coseismic_constant,
    x_obs,
    y_obs,
    n_skip_plot=330,
)

print("Coseismic constant (3x resolution)")
bemcs.plot_displacements_stresses_els(
    els_3,
    n_obs,
    ux_coseismic_constant_3,
    uy_coseismic_constant_3,
    sxx_coseismic_constant_3,
    syy_coseismic_constant_3,
    sxy_coseismic_constant_3,
    x_obs,
    y_obs,
    n_skip_plot=330,
)

print("Coseismic smooth")
bemcs.plot_displacements_stresses_els(
    els,
    n_obs,
    ux_coseismic_smooth,
    uy_coseismic_smooth,
    sxx_coseismic_smooth,
    syy_coseismic_smooth,
    sxy_coseismic_smooth,
    x_obs,
    y_obs,
    n_skip_plot=330,
)

print("Interseismic constant")
bemcs.plot_displacements_stresses_els(
    els,
    n_obs,
    ux_interseismic_constant,
    uy_interseismic_constant,
    sxx_interseismic_constant,
    syy_interseismic_constant,
    sxy_interseismic_constant,
    x_obs,
    y_obs,
    n_skip_plot=330,
)

print("Interseismic constant (3x resolution)")
bemcs.plot_displacements_stresses_els(
    els_3,
    n_obs,
    ux_interseismic_constant_3,
    uy_interseismic_constant_3,
    sxx_interseismic_constant_3,
    syy_interseismic_constant_3,
    sxy_interseismic_constant_3,
    x_obs,
    y_obs,
    n_skip_plot=330,
)

print("Interseismic smooth")
bemcs.plot_displacements_stresses_els(
    els,
    n_obs,
    ux_interseismic_smooth,
    uy_interseismic_smooth,
    sxx_interseismic_smooth,
    syy_interseismic_smooth,
    sxy_interseismic_smooth,
    x_obs,
    y_obs,
    n_skip_plot=330,
)
# Out:
# Coseismic constant
# Coseismic constant (3x resolution)
# Coseismic smooth
# Interseismic constant
# Interseismic constant (3x resolution)
# Interseismic smooth

# %% [markdown]
# # Read in wedge geometry polygon and set up spatial filter

# %%
df = pd.read_csv("mht_wedge_polygon.csv")
inpolygon_vals = bemcs.inpolygon(
    x_obs.flatten(), y_obs.flatten(), df.x.values, df.y.values
)
inpolygon_vals = np.reshape(inpolygon_vals, (n_obs, n_obs))

# %% [markdown]
# # Pretty plotting of coseismic internal strain energy
# 1. Constant slip case
# 2. Constant slip case (3x resolution)
# 3. Smooth slip case
# 4. Residual (constant - smooth)
# 5. Residual (constant (3x resolution) - smooth)

# %%
plt.figure(figsize=(14, 9))

# 1. Constant slip case
plt.subplot(3, 2, 1)
to_plot = u_coseismic_constant.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(6, 10, 5)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} U$ (Pa)",
)
cb.set_ticks([6, 7, 8, 9, 10])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
    linewidth=0.25,
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("a) constant slip BEM")


# 2. Constant slip case (3x elements)
plt.subplot(3, 2, 2)
to_plot = u_coseismic_constant_3.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(6, 10, 5)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} U$ (Pa)",
)
cb.set_ticks([6, 7, 8, 9, 10])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
    linewidth=0.25,
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("a) constant slip BEM (3x elements)")

# 3. Smooth slip case
ax = plt.subplot(3, 2, 3)
middle_bbox = ax.get_position()
middle_bbox.bounds = (0.34, 0.418891694725028, 0.35227272727272724, 0.1522166105499439)
ax.set_position(middle_bbox)
to_plot = u_coseismic_smooth.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot)
to_plot[~inpolygon_vals] = np.nan
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} U$ (Pa)",
)
cb.set_ticks([6, 7, 8, 9, 10])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
    linewidth=0.25,
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("c) smooth slip BEM")

# 5. Residual (percent error)
plt.subplot(3, 2, 5)
to_plot = (
    np.abs(
        u_coseismic_constant.reshape(n_obs, n_obs)
        - u_coseismic_smooth.reshape(n_obs, n_obs)
    )
    / np.abs(u_coseismic_smooth.reshape(n_obs, n_obs))
    * 100
)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(0, 200, 5)
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Greys",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\%$ error",
)
# cb.set_ticks([-3, -2, -1])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
    linewidth=0.25,
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("d) residual")

# 6. Residual (percent error)
plt.subplot(3, 2, 6)
to_plot = (
    np.abs(
        u_coseismic_constant_3.reshape(n_obs, n_obs)
        - u_coseismic_smooth.reshape(n_obs, n_obs)
    )
    / np.abs(u_coseismic_smooth.reshape(n_obs, n_obs))
    * 100
)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(0, 200, 5)
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Greys",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\%$ error",
)
# cb.set_ticks([-3, -2, -1])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
    linewidth=0.25,
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("e) residual (3x elements)")

if save_figures:
    plt.savefig("mht_internal_strain_energy_coseismic.png", dpi=500)
    plt.savefig("mht_internal_strain_energy_coseismic.pdf")
plt.show()
# Out:
# /var/folders/pq/qqjshcd51vg5t9w5ws8wkmw00000gn/T/ipykernel_82345/3479062165.py:24: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(
# /var/folders/pq/qqjshcd51vg5t9w5ws8wkmw00000gn/T/ipykernel_82345/3479062165.py:65: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(
# /var/folders/pq/qqjshcd51vg5t9w5ws8wkmw00000gn/T/ipykernel_82345/3479062165.py:106: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(
# /var/folders/pq/qqjshcd51vg5t9w5ws8wkmw00000gn/T/ipykernel_82345/3479062165.py:151: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(
# /var/folders/pq/qqjshcd51vg5t9w5ws8wkmw00000gn/T/ipykernel_82345/3479062165.py:196: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   plt.contour(

# %% [markdown]
# # Pretty plotting of interseismic internal strain energy
# 1. Constant slip case
# 2. Constant slip case (3x resolution)
# 3. Smooth slip case
# 4. Residual (constant - smooth)
# 5. Residual (constant (3x resolution) - smooth)

# %%
plt.figure(figsize=(14, 9))

# 1. Constant slip case
plt.subplot(3, 2, 1)
to_plot = u_interseismic_constant.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(-13, -11, 7)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} \dot{U}$ (Pa/s)",
)
cb.set_ticks([-13, -12, -11])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("a) constant slip BEM")

# 2. Constant slip case (3x elements)
plt.subplot(3, 2, 2)
to_plot = u_interseismic_constant_3.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot)
to_plot[~inpolygon_vals] = np.nan
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} \dot{U}$ (Pa/s)",
)
cb.set_ticks([-13, -12, -11])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("b) constant slip BEM (3x elements)")

# 3. Smooth slip case
ax = plt.subplot(3, 2, 3)
middle_bbox = ax.get_position()
middle_bbox.bounds = (0.34, 0.418891694725028, 0.35227272727272724, 0.1522166105499439)
ax.set_position(middle_bbox)
to_plot = u_interseismic_smooth.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot)
to_plot[~inpolygon_vals] = np.nan
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} \dot{U}$ (Pa/s)",
)
cb.set_ticks([-13, -12, -11])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("c) smooth slip BEM")

# 5. Residual
plt.subplot(3, 2, 5)
to_plot = (
    np.abs(
        u_interseismic_constant.reshape(n_obs, n_obs)
        - u_interseismic_smooth.reshape(n_obs, n_obs)
    )
    / np.abs(u_interseismic_smooth.reshape(n_obs, n_obs))
    * 100
)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(0, 200, 5)
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Greys",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\%$ error",
)
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("d) residual")

# 5. Residual
plt.subplot(3, 2, 6)
to_plot = (
    np.abs(
        u_interseismic_constant_3.reshape(n_obs, n_obs)
        - u_interseismic_smooth.reshape(n_obs, n_obs)
    )
    / np.abs(u_interseismic_smooth.reshape(n_obs, n_obs))
    * 100
)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(0, 200, 5)
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Greys",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\%$ error",
)
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("e) residual (3x elements)")


if save_figures:
    plt.savefig("mht_internal_strain_energy_interseismic.png", dpi=500)
    plt.savefig("mht_internal_strain_energy_interseismic.pdf")

plt.show()

# %% [markdown]
# # Pretty plot coseismic first stress invariant
# 1. Constant slip case
# 2. Constant slip case (3x resolution)
# 3. Smooth slip case
# 4. Residual (constant - smooth)
# 5. Residual (constant (3x resolution) - smooth)

# %%
plt.figure(figsize=(14, 9))

# 1. Constant slip case
plt.subplot(3, 2, 1)
i1_constant = (sxx_coseismic_constant + syy_coseismic_constant).reshape(n_obs, n_obs)
toplot = i1_constant
toplot[~inpolygon_vals] = np.nan
levels = np.linspace(-0.5, 0.5, 20)
levels = np.linspace(-1e10, 1e10, 20)
# levels = 10

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    toplot,
    cmap="bwr",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\mathrm{I}_{1}$ (Pa)",
)
cb.set_ticks([-1e10, 0, 1e10])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    toplot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)

plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("a) constant slip BEM")


# 2. Constant slip case (3x elements)
plt.subplot(3, 2, 2)
i1_constant_3 = (sxx_coseismic_constant_3 + syy_coseismic_constant_3).reshape(
    n_obs, n_obs
)
toplot = i1_constant_3
toplot[~inpolygon_vals] = np.nan
# levels = np.linspace(-1.0, 1.0, 20)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    toplot,
    cmap="bwr",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\mathrm{I}_{1}$ (Pa)",
)
cb.set_ticks([-1e10, 0, 1e10])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    toplot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)

plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("b) constant slip BEM (3x elements)")


# 3. Smooth
ax = plt.subplot(3, 2, 3)
middle_bbox = ax.get_position()
middle_bbox.bounds = (0.34, 0.418891694725028, 0.35227272727272724, 0.1522166105499439)
ax.set_position(middle_bbox)
i1_smooth = (sxx_coseismic_smooth + syy_coseismic_smooth).reshape(n_obs, n_obs)
to_plot = i1_smooth
to_plot[~inpolygon_vals] = np.nan
# levels = np.linspace(-1.0, 1.0, 20)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="bwr",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\mathrm{I}_{1}$ (Pa)",
)
cb.set_ticks([-1e10, 0, 1e10])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)

plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("c) smooth slip BEM")


# 4. Residual percent error
plt.subplot(3, 2, 5)
to_plot = (
    np.abs(i1_constant.reshape(n_obs, n_obs) - i1_smooth.reshape(n_obs, n_obs))
    / np.abs(i1_smooth.reshape(n_obs, n_obs))
    * 100
)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(0, 200, 5)
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Greys",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\%$ error",
)
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("d) residual")

# 5. Residual percent error (3x resolution)
plt.subplot(3, 2, 6)
to_plot = (
    np.abs(i1_constant_3.reshape(n_obs, n_obs) - i1_smooth.reshape(n_obs, n_obs))
    / np.abs(i1_smooth.reshape(n_obs, n_obs))
    * 100
)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(0, 200, 5)
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Greys",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\%$ error",
)
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("e) residual")

if save_figures:
    plt.savefig("mht_internal_I1_coseismic.png", dpi=500)
    plt.savefig("mht_internal_I1_coseismic.pdf")

plt.show()

# %% [markdown]
# # Pretty plot interseismic first stress invariant
# 1. Constant slip case
# 2. Constant slip case (3x resolution)
# 3. Smooth slip case
# 4. Residual (constant - smooth)
# 5. Residual (constant (3x resolution) - smooth)

# %%
plt.figure(figsize=(14, 9))

# 1. Constant slip case
plt.subplot(3, 2, 1)
i1_constant = (sxx_interseismic_constant + syy_interseismic_constant).reshape(
    n_obs, n_obs
)
toplot = i1_constant
toplot[~inpolygon_vals] = np.nan
levels = np.linspace(-1, 1, 20)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    toplot,
    cmap="bwr",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\mathrm{I}_{1}$ (Pa/s)",
)
cb.set_ticks([-1, 0, 1])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    toplot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)

plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("a) constant slip BEM")

# 2. Constant slip case (3x resolution)
plt.subplot(3, 2, 2)
i1_constant_3 = (sxx_interseismic_constant_3 + syy_interseismic_constant_3).reshape(
    n_obs, n_obs
)
toplot = i1_constant_3
toplot[~inpolygon_vals] = np.nan
# levels = np.linspace(-1.0, 1.0, 20)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    toplot,
    cmap="bwr",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\mathrm{I}_{1}$ (Pa/s)",
)
cb.set_ticks([-1, 0, 1])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    toplot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)

plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("b) constant slip BEM (3x elements)")


# 3. Smooth
ax = plt.subplot(3, 2, 3)
middle_bbox = ax.get_position()
middle_bbox.bounds = (0.34, 0.418891694725028, 0.35227272727272724, 0.1522166105499439)
ax.set_position(middle_bbox)
i1_smooth = (sxx_interseismic_smooth + syy_interseismic_smooth).reshape(n_obs, n_obs)
to_plot = i1_smooth
to_plot[~inpolygon_vals] = np.nan
# levels = np.linspace(-1.0, 1.0, 20)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="bwr",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\mathrm{I}_{1}$ (Pa/s)",
)
cb.set_ticks([-1, 0, 1])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)

plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("c) smooth slip BEM")

# 4. Residual percent error
plt.subplot(3, 2, 5)
to_plot = (
    np.abs(i1_constant.reshape(n_obs, n_obs) - i1_smooth.reshape(n_obs, n_obs))
    / np.abs(i1_smooth.reshape(n_obs, n_obs))
    * 100
)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(0, 200, 5)
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Greys",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\%$ error",
)
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("d) residual")

# 5. Residual percent error (3x elements)
plt.subplot(3, 2, 6)
to_plot = (
    np.abs(i1_constant_3.reshape(n_obs, n_obs) - i1_smooth.reshape(n_obs, n_obs))
    / np.abs(i1_smooth.reshape(n_obs, n_obs))
    * 100
)
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(0, 200, 5)
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Greys",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.40, 0.3, 0.035)),
    orientation="horizontal",
    label="$\%$ error",
)
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("e) residual (3x elements)")


if save_figures:
    plt.savefig("mht_internal_I1_interseismic.png", dpi=500)
    plt.savefig("mht_internal_I1_interseismic.pdf")
plt.show()

# %% [markdown]
# # Strain energy accumulation (interseismic) and release (Gorkha)

# %%
plt.figure(figsize=(10, 11))

levels = np.linspace(6, 10, 5)
levels = 10

# 1. Smooth slip interseismic
ax = plt.subplot(3, 1, 1)
to_plot = u_interseismic_smooth_1000_years.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot.astype(float))
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(5, 9, 7)
# levels = 10
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.30, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} \dot{U}$ (Pa/s)",
)
cb.set_ticks([5, 7, 9])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("a) interseismic, 1000 years")


# 2. Smooth slip coseismic
ax = plt.subplot(3, 1, 2)
to_plot = u_coseismic_smooth.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot)
to_plot[~inpolygon_vals] = np.nan
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.30, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} U$ (Pa)",
)
cb.set_ticks([5, 7, 9])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("b) coseismic")


# 3. Residual
ax = plt.subplot(3, 1, 3)
residual_u = u_interseismic_smooth_1000_years - u_coseismic_smooth
to_plot = residual_u.reshape(n_obs, n_obs).astype(float)
# to_plot = np.log10(np.abs(to_plot))
to_plot[~inpolygon_vals] = np.nan
# to_plot[to_plot < 0] = np.nan
# to_plot = np.log10(np.abs(to_plot))
levels = np.linspace(-1e9, 1e9, 8)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="bwr",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.30, 0.3, 0.035)),
    orientation="horizontal",
    label="$\Delta U$ (Pa)",
)
cb.set_ticks([-1e9, 0, 1e9])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("c) residual")

if save_figures:
    plt.savefig("mht_interseismic_coseismic_residual.png", dpi=500)
    plt.savefig("mht_interseismic_coseismic_residual.pdf")
plt.show()

# %% [markdown]
# # Try linear scaling of strain energy

# %%
plt.figure(figsize=(10, 11))

levels = np.linspace(6, 10, 5)
levels = 10

# 1. Smooth slip interseismic
years = 2e3
ax = plt.subplot(3, 1, 1)
to_plot = yr_to_s**2 * years**2 * u_interseismic_smooth.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot.astype(float))
to_plot[~inpolygon_vals] = np.nan
levels = np.linspace(5, 9, 7)
# levels = 10
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.30, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} U$ (Pa)",
)
cb.set_ticks([5, 7, 9])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("a) interseismic, 1000 years")


# 2. Smooth slip coseismic
ax = plt.subplot(3, 1, 2)
to_plot = u_coseismic_smooth.reshape(n_obs, n_obs)
to_plot = np.log10(to_plot)
to_plot[~inpolygon_vals] = np.nan
plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="Wistia",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.30, 0.3, 0.035)),
    orientation="horizontal",
    label="$\log_{10} U$ (Pa)",
)
cb.set_ticks([5, 7, 9])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("b) coseismic")


# 3. Residual
ax = plt.subplot(3, 1, 3)
residual_u = (yr_to_s**2 * years**2 * u_interseismic_smooth) - u_coseismic_smooth
to_plot = residual_u.reshape(n_obs, n_obs).astype(float)
# to_plot = np.log10(np.abs(to_plot))
to_plot[~inpolygon_vals] = np.nan
# to_plot[to_plot < 0] = np.nan
# to_plot = np.log10(np.abs(to_plot))
levels = np.linspace(-1e9, 1e9, 8)

plt.contourf(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    cmap="bwr",
    extend="both",
    levels=levels,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.05, 0.30, 0.3, 0.035)),
    orientation="horizontal",
    label="$\Delta U$ (Pa)",
)
cb.set_ticks([-1e9, 0, 1e9])
plt.contour(
    x_obs.reshape(n_obs, n_obs),
    y_obs.reshape(n_obs, n_obs),
    to_plot,
    linewidths=0.25,
    colors="k",
    levels=levels,
    linestyles="-",
)
for i in range(n_els):
    plt.plot([els.x1[i], els.x2[i]], [els.y1[i], els.y2[i]], "k-", linewidth=1.0)
plt.xlim([-175, 5])
plt.ylim([np.min(y_obs), np.max(y_obs)])
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x (km)")
plt.ylabel("depth (km)")
plt.title("c) residual")

if save_figures:
    plt.savefig("mht_interseismic_coseismic_residual.png", dpi=500)
    plt.savefig("mht_interseismic_coseismic_residual.pdf")
plt.show()

# %% [markdown]
# # Numpy save a bunch of stuff because this takes so long to run (~10 hours)

# %%
np.savez(
    "example_hrf_constantslip_vs_bemcs_nice_figures_all_5_correct_input.ipynb.npz",
    sxx_coseismic_constant=sxx_coseismic_constant,
    syy_coseismic_constant=syy_coseismic_constant,
    sxy_coseismic_constant=sxy_coseismic_constant,
    sxx_coseismic_constant_3=sxx_coseismic_constant_3,
    syy_coseismic_constant_3=syy_coseismic_constant_3,
    sxy_coseismic_constant_3=sxy_coseismic_constant_3,
    sxx_coseismic_smooth=sxx_coseismic_smooth,
    syy_coseismic_smooth=syy_coseismic_smooth,
    sxy_coseismic_smooth=sxy_coseismic_smooth,
    sxx_interseismic_constant=sxx_interseismic_constant,
    syy_interseismic_constant=syy_interseismic_constant,
    sxy_interseismic_constant=sxy_interseismic_constant,
    sxx_interseismic_constant_3=sxx_interseismic_constant_3,
    syy_interseismic_constant_3=syy_interseismic_constant_3,
    sxy_interseismic_constant_3=sxy_interseismic_constant_3,
    sxx_interseismic_smooth=sxx_interseismic_smooth,
    syy_interseismic_smooth=syy_interseismic_smooth,
    sxy_interseismic_smooth=sxy_interseismic_smooth,
    u_coseismic_constant=u_coseismic_constant,
    u_coseismic_constant_3=u_coseismic_constant_3,
    u_coseismic_smooth=u_coseismic_smooth,
    u_interseismic_constant=u_interseismic_constant,
    u_interseismic_constant_3=u_interseismic_constant_3,
    u_interseismic_smooth=u_interseismic_smooth,
    u_interseismic_smooth_250_years=u_interseismic_smooth_250_years,
    u_interseismic_smooth_500_years=u_interseismic_smooth_500_years,
    u_interseismic_smooth_1000_years=u_interseismic_smooth_1000_years,
    x_obs=x_obs,
    y_obs=y_obs,
    inpolygon_vals=inpolygon_vals,
    x1=els.x1,
    x2=els.x2,
    y1=els.y1,
    y2=els.y2,
    coefs_coseismic_constant=coefs_coseismic_constant,
    coefs_coseismic_constant_3=coefs_coseismic_constant_3,
    coefs_coseismic_smooth=coefs_coseismic_smooth,
    coefs_interseismic_constant=coefs_interseismic_constant,
    coefs_interseismic_constant_3=coefs_interseismic_constant_3,
    coefs_interseismic_smooth=coefs_interseismic_smooth,
)

# %% [markdown]
# # Experiments with strain energy calculation

# %%
line_width = 0.5
plt.figure(figsize=(10, 5))
plt.plot(u_interseismic_smooth_250_years, "rx", label="250", linewidth=line_width)
plt.plot(u_interseismic_smooth_500_years, "b.", label="500", linewidth=line_width)
plt.plot(
    2 * u_interseismic_smooth_250_years, "g+", label="2 x 250", linewidth=line_width
)
plt.plot(
    4 * u_interseismic_smooth_250_years, "c^", label="4 x 250", linewidth=line_width
)
plt.legend()
plt.show()
